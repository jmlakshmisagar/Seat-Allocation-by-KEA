# %%
import pandas as pd

# %%
df = pd.read_csv('first-round-cutoff.csv')

# %%
df
# Out:
#     College Code    1G   1H    2AG    2AH    2BG    2BH    3AG    3AH    3BG  \
# 0         C412MC  4654   --  12108   9226   7193  15497   2542     --   6240
# 1         C423MC  2283  154  13131     --   1096     --     --  11138     --
# 2         C495MC  6824  157  14264  13064  13080   9156  11739     --  12997
# 3         C496MC  5243   --  14914   1124   5423     --   4973     --  12327
# 4         C497MC  2244   --  14954    778   8005     --   6051     --  15194
# ..           ...   ...  ...    ...    ...    ...    ...    ...    ...    ...
# 109       C520MC  1665   --  11249  13380   1054     --   4435     --  12433
# 110       C521MC   362   --    972     --   6294   2177   3518     --   1840
# 111       C543MC  3714   --  14949  14675   5655     --    731     --   6863
# 112       C568MC  3613   --   9704  13344    683     --   1265     --   2645
# 113       C575MC  3953   --  15575    784   6229     --   3206     --  14120
#
# ...
