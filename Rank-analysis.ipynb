# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Rank-List-attribute.csv')

# %%
df.head()
# Out:
#    CET number                    Name  Marks Rank
# 0   115200463        H R SHREE RAKSHA     72    1
# 1   103200234        ADITI NARASIMHAN     71    2
# 2   113200118  DARSHAN PRASHANT HEGDE     70    3
# 3   149200155         ROHIT KOUJALAGI     68    4
# 4   101200497             U S ABHIRAM     68    5

# %%
plt.figure(figsize=(10,12))
sns.scatterplot(x='Rank',y ='Marks',data=df)    
plt.show()

# %%
df['Marks'].value_counts().sort_index()
# Out:
# Marks
# 11      1
# 13      3
# 14      2
# 15      4
# 16      3
# 17     14
# 18     24
# 19     35
# 20     57
# 21     73
# 22    138
# 23    203
# 24    253
# 25    354
# 26    420
# 27    506
# 28    565
# 29    718
# 30    693
# 31    782
# 32    813
# 33    890
# 34    817
# 35    806
# 36    812
# 37    760
# 38    706
# 39    674
# 40    558
# 41    548
# 42    489
# 43    418
# 44    358
# 45    307
# 46    319
# 47    232
# 48    211
# 49    182
# 50    152
# 51    114
# 52    107
# 53     82
# 54     59
# 55     67
# 56     47
# 57     49
# 58     21
# 59     25
# 60     18
# 61     17
# 62      7
# 63     10
# 64      9
# 65      8
# 66      6
# 67      5
# 68      3
# 70      1
# 71      1
# 72      1
# Name: count, dtype: int64

# %%
sns.boxplot(x='Rank',y ='Marks',data=df)
# Out:
# <AxesSubplot: xlabel='Rank', ylabel='Marks'>
