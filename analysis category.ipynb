# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('final_seat_availability.csv')

# %%
df.columns
# Out:
# Index(['College Code', '1G', '1H', '2AG', '2AH', '2BG', '2BH', '3AG', '3AH',
#        '3BG', '3BH', 'GM', 'GMH', 'NKN', 'PH', 'SCG', 'SCH', 'STG', 'STH',
#        'XD', 'Total Seats'],
#       dtype='object')

# %%
sns.scatterplot(x='GM', y='Total Seats',hue='2AG',data=df)
# Out:
# <AxesSubplot: xlabel='GM', ylabel='Total Seats'>
