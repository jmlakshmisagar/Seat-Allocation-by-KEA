# %%
import pandas as pd

# %%
df=pd.read_csv('college_seats_cleaned.csv')

# %%
df
# Out:
#     College Code   1G  1H  2AG  2AH  2BG  2BH  3AG  3AH  3BG  ...  GM  GMH  \
# 0         C412MC    2   0    8    1    2    1    2    0    2  ...  23    2
# 1         C423MC    1   2    2    4    1    1    0    2    0  ...   6   13
# 2         C495MC    7   1   23    2    6    1    6    0    8  ...  69    6
# 3         C496MC    4   0   16    1    4    0    5    0    5  ...  46    4
# 4         C497MC    4   0   16    1    4    0    4    0    6  ...  46    4
# ..           ...  ...  ..  ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 132       C543MC    2   0    6    1    2    0    1    0    2  ...  19    1
# 133       C546MC  735   0    1    2    5    1    2    0    1  ...   2    6
# 134       C551MC  648   1    0    3    0    1    0    1    0  ...   0    9
# 135       C568MC    1   0    3    1    1    0    1    0    1  ...   9    1
# 136       C575MC    4   0   16    1    4    0    4    0    5  ...  46    4
#
#      NKN  PH  SCG  SCH  STG  STH  XD  Total Seats
# ...

# %%
categories = ['1G', '1H', '2AG', '2AH', '2BG', '2BH', '3AG', '3AH',
              '3BG', '3BH', 'GM', 'GMH', 'NKN', 'PH', 'SCG', 'SCH', 'STG', 'STH', 'XD']

df['Sum'] = df[categories].sum(axis=1)
filtered_df = df[df['Sum'] == df['Total Seats']]
filtered_df = filtered_df.drop(columns=['Sum'])

filtered_df
# Out:
#     College Code  1G  1H  2AG  2AH  2BG  2BH  3AG  3AH  3BG  ...  GM  GMH  \
# 0         C412MC   2   0    8    1    2    1    2    0    2  ...  23    2
# 1         C423MC   1   2    2    4    1    1    0    2    0  ...   6   13
# 2         C495MC   7   1   23    2    6    1    6    0    8  ...  69    6
# 3         C496MC   4   0   16    1    4    0    5    0    5  ...  46    4
# 4         C497MC   4   0   16    1    4    0    4    0    6  ...  46    4
# ..           ...  ..  ..  ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 129       C520MC   1   0    7    1    1    0    1    0    3  ...  19    1
# 130       C521MC   1   0    3    0    1    1    1    0    1  ...   9    1
# 132       C543MC   2   0    6    1    2    0    1    0    2  ...  19    1
# 135       C568MC   1   0    3    1    1    0    1    0    1  ...   9    1
# 136       C575MC   4   0   16    1    4    0    4    0    5  ...  46    4
#
#      NKN  PH  SCG  SCH  STG  STH  XD  Total Seats
# ...

# %%
filtered_df.to_csv('final_seat_availability.csv', index=False)
